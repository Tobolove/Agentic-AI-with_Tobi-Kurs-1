# %% [markdown]
# # Parrallelization in Agentic Workflows
# Wir nutzen Best Practices um unsere Agenten zu instanzieren.

# %%
import os
from openai import AzureOpenAI
from dotenv import load_dotenv

# Load environment variables and initialize OpenAI client
load_dotenv()

# Azure OpenAI Configuration - following the pattern you showed
api_key = os.getenv("AZURE_OPENAI_API_KEY")
azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
azure_deployment = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")
api_version = os.getenv("AZURE_OPENAI_API_VERSION", "2024-02-01")

# Model name should match your Azure deployment name
model = azure_deployment if azure_deployment else "gpt-4o-mini"

if not api_key or not azure_endpoint:
    raise ValueError("Azure OpenAI configuration missing. Please set AZURE_OPENAI_API_KEY, AZURE_OPENAI_ENDPOINT, and AZURE_OPENAI_DEPLOYMENT_NAME in your .env file.")

# Configure client for Azure OpenAI
client = AzureOpenAI(
    api_key=api_key,
    api_version=api_version,
    azure_endpoint=azure_endpoint,
)

# --- Helper Function for API Calls ---
def call_openai(system_prompt, user_prompt, model=model, temperature=0.0):
    """Simple wrapper for OpenAI API calls."""
    try:
        response = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ],
            temperature=0.0
        )
        return response.choices[0].message.content
    except Exception as e:
        return f"An error occurred: {e}"

# %% [markdown]
# # Base Agent Classes
# Wir erstellen eine BaseAgent-Klasse. Sie dient als Vorlage und stellt sicher, dass jeder Agent, den wir bauen, eine gemeinsame Struktur hat
# Die execute-Methode ist hier bewusst leer und wirft einen Fehler. Das ist ein Design-Pattern, das uns zwingt, für jeden spezialisierten Agenten, den wir davon ableiten, eine eigene, konkrete execute-Logik zu implementieren.

# %%
# agent_classes.py
class BaseAgent:
    """Eine Basisklasse, die die Grundstruktur für alle Agenten definiert."""
    def __init__(self, name: str, persona: str, client):
        self.name = name
        self.persona = persona
        self.client = client

    def execute(self, task: str, context: str = "") -> str:
        """Die Kernmethode, die von spezialisierten Agenten überschrieben wird."""
        raise NotImplementedError("Die 'execute'-Methode muss von einer Subklasse implementiert werden.")

# %% [markdown]
# # Spezialisierte Agent Classes
# Alle Agent Klassen erben von der BaseAgent-Klasse. Das bedeutet, sie bekommt automatisch die __init__-Methode.
# Wir implementieren hier nur die execute-Methode und die tet_description method. Sie nimmt eine Aufgabe und optionalen Kontext entgegen, verpackt alles in einen System- und einen User-Prompt und ruft die OpenAI-API auf.

# %%
# classes.py
class TechnologyAgent(BaseAgent):
    """Ein Agent, der auf die Recherche von Technologischen Trends spezialisiert ist."""

    def __init__(self, temperature=0.0):
        name = "Technology Expert"
        persona = "Du bist ein erfahrener Technologie-Analyst. Du recherchierst nur Informationen zu technologischen Trends"
        
        super().__init__(name, persona, client)
        self.temperature = temperature
        self.description = f"Dieser Agent heisst: {self.name.lower()}. Er kann recherchieren und Informationen zu technologischen Trends sammeln."

    def get_description(self):
        """Returns the agent's description."""
        return self.description

    def execute(self, task: str) -> str:
        print(f"INFO: {self.name} führt Recherche für '{task}' aus...")
        system_prompt = self.persona
        user_prompt = f"Recherchiere das folgende Thema aus deiner Perspektive: {task}"
        response = call_openai(
            model=model,
            system_prompt=system_prompt,
            user_prompt=user_prompt,
            temperature=self.temperature
        )
        return response


class MarketAnalysis(BaseAgent):
    """Ein Agent, der die Markt-Dynamiken recherchiert"""

    def __init__(self):
        name = "Market Analyst"
        persona = "Du bist ein erfahrener Markt-Analyst. Du recherchierst nur Informationen zu Marktdynamiken und wie sich ein Markt entwickelt"
        super().__init__(name, persona, client)
        self.description = f"Dieser Agent heisst: {self.name.lower()}. Er kann informationen zu Market Trends recherchieren"

    def get_description(self):
        """Returns the agent's description."""
        return self.description

    def execute(self, text: str) -> str:
        print(f"INFO: {self.name} übersetzt und fasst den Text zusammen...")
        system_prompt = self.persona
        user_prompt = f"Recherchiere das folgende Thema aus deiner Perspektive:\n\n{text}"
        response = call_openai(
            model=model,
            system_prompt=system_prompt,
            user_prompt=user_prompt
        )
        return response


class RegulationAgent(BaseAgent):
    """Ein Agent, der Regulationen in der Schweiz recherchiert"""

    def __init__(self):
        name = "Regulation Expert"
        persona = "Du bist ein erfahrener Regulationen-Spezialist. Du sammelst nur Informationen zu Regulationen zu einem Thema in der Schweiz."
        super().__init__(name, persona, client)
        self.description = f"Dieser Agent heisst: {self.name.lower()}. Er kann Informationen zu aktuellen Schweizer Regulationen sammeln."

    def get_description(self):
        """Returns the agent's description."""
        return self.description

    def execute(self, text: str) -> str:
        print(f"INFO: {self.name} überprüft die Fakten...")
        system_prompt = self.persona
        user_prompt = f"Recherchiere zum folgenden Thema aus deiner Perspektive:\n\n{text}"
        response = call_openai(
            model=model,
            system_prompt=system_prompt,
            user_prompt=user_prompt
        )
        return response


class SummaryAgent:
    def __init__(self):
        self.client = client

    def run(self, text, inputs):
        combined_prompt = (
            f"The user asked: '{text}'\n\n"
            f"Here are the expert responses:\n"
            f"- Policy Expert: {inputs['policy']}\n\n"
            f"- Technology Expert: {inputs['tech']}\n\n"
            f"- Market Expert: {inputs['market']}\n\n"
            "Please summarize the combined insights into a single clear and concise response."
        )
        print(f"Summary Agent resolving prompt: {combined_prompt}")

        response = self.client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": "You are an energy strategist skilled at synthesizing expert insights."},
                {"role": "user", "content": combined_prompt}
            ],
            temperature=0.7,
        )
        return response.choices[0].message.content

# %% [markdown]
# # Threading das Herzstück

# %%
import threading

agent_outputs = {}

# The shared user prompt
user_prompt = "What are current trends shaping the future of the energy industry?"

# %%
def main():
           # Initialize agents - corrected parameters
           policy_agent = RegulationAgent()
           tech_agent = TechnologyAgent(temperature=2.0)
           market_agent = MarketAnalysis()
           summary_agent = SummaryAgent()

           # Funktion um alle Agenten zu starten und unter dem jeweiligen Key die ergebnisse zu speichern.
           def run_agent(agent, key):
               agent_outputs[key] = agent.execute(user_prompt)

           # Hier erstellen wir die Threads für die Parallele Execution
           threads = [
               threading.Thread(target=run_agent, args=(policy_agent, "policy")),
               threading.Thread(target=run_agent, args=(tech_agent, "tech")),
               threading.Thread(target=run_agent, args=(market_agent, "market"))
           ]

           # Start all threads gleichtzeitig
           for t in threads:
               t.start()

           # Wait for all threads zum fertigstellen
           for t in threads:
               t.join()

           # Starte den Zusammenfassungs Agent um auf Basis aller Ergebnisse in den Threads den Report zu schreiben.
           final_summary = summary_agent.run(user_prompt, agent_outputs)

           print("\n=== FINAL SUMMARY ===\n")
           print(final_summary)

if __name__ == "__main__":
    main()
# Out:
# INFO: Regulation Expert überprüft die Fakten...
# INFO: Technology Expert führt Recherche für 'What are current trends shaping the future of the energy industry?' aus...
# INFO: Market Analyst übersetzt und fasst den Text zusammen...
# Summary Agent resolving prompt: The user asked: 'What are current trends shaping the future of the energy industry?'
#
# Here are the expert responses:
# - Policy Expert: In der Schweiz beeinflussen verschiedene regulatorische Trends die zukünftige Entwicklung der Energiebranche. Hier eine Übersicht der wichtigsten aktuellen regulatorischen Entwicklungen und Trends:
#
# 1. **Energiegesetz (EnG) und Energiestrategie 2050**
#    Die Energiestrategie 2050 der Schweiz zielt auf eine nachhaltige Energieversorgung ab, mit Fokus auf Energieeffizienz, Ausbau erneuerbarer Energien und Reduktion fossiler Brennstoffe. Das revidierte Energiegesetz (EnG), das seit 2018 in Kraft ist, fördert den Ausbau von Solar-, Wind- und Wasserkraft sowie die Verbesserung der Energieeffizienz in Gebäuden und Industrie.
#
# 2. **Förderprogramme und Subventionen**
#    Die Schweiz setzt verstärkt auf Förderprogramme wie die Kostendeckende Einspeisevergütung (KEV) und Investitionsbeiträge für erneuerbare Energien. Diese Programme werden kontinuierlich angepasst, um den Ausbau von Photovoltaik, Biomasse und anderen erneuerbaren Technologien zu beschleunigen.
#
# 3. **Netzzugang und Marktliberalisierung**
#    Die Regulierung des Netzzugangs wird weiterentwickelt, um den Wettbewerb im Strommarkt zu fördern und die Integration dezentraler Erzeuger (z.B. private Solaranlagen) zu erleichtern. Die Bundesnetzagentur (ElCom) überwacht die Einhaltung der Netzregeln und sorgt für Transparenz bei Netznutzungsentgelten.
#
# 4. **Dekarbonisierung und CO2-Gesetz**
#    Das revidierte CO2-Gesetz, das 2023 in Kraft trat, setzt strengere Emissionsziele und fördert den Umstieg auf klimafreundliche Technologien. Es beinhaltet auch Maßnahmen zur Förderung von Elektromobilität und nachhaltiger Wärmeversorgung.
#
# 5. **Digitalisierung und Smart Grids**
#    Regulatorische Rahmenbedingungen werden angepasst, um die Einführung von Smart Grids, intelligenten Messsystemen (Smart Meter) und digitalen Plattformen zu unterstützen. Dies ermöglicht eine effizientere Steuerung von Energieerzeugung und -verbrauch.
#
# 6. **Sicherheit und Versorgungssicherheit**
#    Die Schweiz legt großen Wert auf Versorgungssicherheit, insbesondere im Kontext der Energiewende. Regulatorische Vorgaben zur Netzstabilität, Notfallreserven und Importabhängigkeit werden laufend überprüft und angepasst.
#
# 7. **Internationale Zusammenarbeit**
#    Die Schweiz harmonisiert ihre Energiepolitik zunehmend mit EU-Richtlinien, insbesondere im Bereich Marktintegration und erneuerbare Energien, trotz Nicht-EU-Mitgliedschaft.
#
# Diese regulatorischen Trends prägen die Schweizer Energiebranche und treiben den Wandel hin zu einer nachhaltigen, effizienten und sicheren Energieversorgung voran.
#
# - Technology Expert: Aktuelle Trends, die die Zukunft der Energiebranche prägen, lassen sich aus technologischer Perspektive wie folgt zusammenfassen:
#
# 1. **Erneuerbare Energien und Dekarbonisierung**
#    Der Übergang von fossilen Brennstoffen zu erneuerbaren Energiequellen wie Solar, Wind, Wasserkraft und Geothermie ist der dominierende Trend. Technologische Fortschritte in der Effizienz und Kostensenkung von Solarpanels und Windturbinen treiben diese Entwicklung voran. Gleichzeitig gewinnen Technologien zur CO2-Abscheidung und -Speicherung (CCS) an Bedeutung, um Emissionen in bestehenden Anlagen zu reduzieren.
#
# 2. **Dezentralisierung und Digitalisierung**
#    Die Energieerzeugung verlagert sich zunehmend von zentralen Großkraftwerken hin zu dezentralen, oft erneuerbaren Erzeugern, z.B. auf Hausdächern oder in Gemeinden. Dies erfordert intelligente Netze (Smart Grids), die mithilfe von IoT-Sensoren, KI und Big Data den Energiefluss in Echtzeit steuern und optimieren können. Blockchain-Technologien werden ebenfalls erprobt, um Peer-to-Peer-Energiehandel zu ermöglichen.
#
# 3. **Energiespeicherung und Flexibilisierung**
#    Die Integration von Energiespeichern, insbesondere Batterien (Lithium-Ionen, Festkörperbatterien) und Power-to-X-Technologien (Umwandlung von Strom in Wasserstoff oder synthetische Kraftstoffe), ist entscheidend, um die Volatilität erneuerbarer Energien auszugleichen. Fortschritte in der Speichertechnologie erhöhen die Netzstabilität und ermöglichen eine flexiblere Energieversorgung.
#
# 4. **Wasserstoff als Energieträger**
#    Grüner Wasserstoff, erzeugt durch Elektrolyse mit erneuerbarem Strom, gilt als Schlüsseltechnologie für die Dekarbonisierung schwer zu elektrifizierender Sektoren wie Industrie, Schifffahrt und Luftfahrt. Technologische Innovationen in der Elektrolyse und Infrastrukturentwicklung sind hier zentral.
#
# 5. **Künstliche Intelligenz und Automatisierung**
#    KI wird eingesetzt, um Energieerzeugung, -verteilung und -verbrauch zu optimieren. Beispielsweise können Vorhersagemodelle für Wetter und Verbrauch Lastmanagement verbessern, während automatisierte Steuerungssysteme die Effizienz steigern.
#
# 6. **Elektromobilität und Sektorkopplung**
#    Die zunehmende Verbreitung von Elektrofahrzeugen verändert die Energienachfrage und bietet gleichzeitig neue Möglichkeiten für Energiespeicherung und Lastmanagement (Vehicle-to-Grid). Die Kopplung von Strom-, Wärme- und Verkehrssektor (Sektorkopplung) wird durch digitale Steuerungssysteme vorangetrieben.
#
# Zusammenfassend lässt sich sagen, dass die Energiebranche durch eine Kombination aus erneuerbaren Energien, Digitalisierung, Energiespeicherung und neuen Energieträgern wie Wasserstoff transformiert wird. Technologische Innovationen in diesen Bereichen sind entscheidend, um eine nachhaltige, flexible und effiziente Energiezukunft zu gestalten.
#
# - Market Expert: Aktuelle Trends, die die Zukunft der Energiebranche prägen, lassen sich aus Marktdynamiken und technologischen Entwicklungen ableiten. Hier eine Übersicht der wichtigsten Einflussfaktoren:
#
# 1. **Energiewende und Dekarbonisierung**
#    Der globale Druck zur Reduktion von CO2-Emissionen führt zu einem verstärkten Fokus auf erneuerbare Energien wie Solar, Wind, Wasserkraft und Biomasse. Regulatorische Rahmenbedingungen, wie CO2-Steuern und Emissionshandelssysteme, treiben Investitionen in saubere Technologien voran.
#
# 2. **Dezentralisierung und Digitalisierung**
#    Die Energieerzeugung verlagert sich zunehmend von zentralen Großkraftwerken hin zu dezentralen, oft kleineren Erzeugungseinheiten (z.B. Photovoltaik-Anlagen auf Dächern). Gleichzeitig ermöglichen digitale Technologien (Smart Grids, IoT, KI) eine effizientere Steuerung und Integration dieser vielfältigen Energiequellen.
#
# 3. **Speichertechnologien und Flexibilisierung**
#    Um die Volatilität erneuerbarer Energien auszugleichen, gewinnen Energiespeicher (Batterien, Power-to-X, Pumpspeicher) an Bedeutung. Flexibilitätsoptionen wie Demand Response und virtuelle Kraftwerke werden wichtiger, um Angebot und Nachfrage in Echtzeit zu balancieren.
#
# 4. **Elektrifizierung und Sektorenkopplung**
#    Die Elektrifizierung von Verkehr, Industrie und Gebäuden ist ein zentraler Trend. Durch die Kopplung verschiedener Sektoren (z.B. Strom, Wärme, Mobilität) entstehen neue Geschäftsmodelle und Synergien, die den Energieverbrauch effizienter gestalten.
#
# 5. **Neue Marktmodelle und Geschäftsstrategien**
#    Energieversorger und neue Marktteilnehmer entwickeln innovative Geschäftsmodelle, z.B. Peer-to-Peer-Handel, Energie-Communities oder Abonnements für Energie-Dienstleistungen. Regulierung und Marktmechanismen passen sich an diese Veränderungen an.
#
# 6. **Internationale Vernetzung und Energiesicherheit**
#    Der Ausbau grenzüberschreitender Stromnetze und der Handel mit erneuerbarer Energie gewinnen an Bedeutung, um Versorgungssicherheit zu gewährleisten und regionale Schwankungen auszugleichen.
#
# Zusammenfassend lässt sich sagen, dass die Energiebranche durch eine Kombination aus technologischer Innovation, regulatorischem Wandel und veränderten Verbraucheranforderungen in eine Phase tiefgreifender Transformation eintritt. Unternehmen, die flexibel auf diese Trends reagieren und in nachhaltige Technologien investieren, werden langfristig wettbewerbsfähig bleiben.
#
# Please summarize the combined insights into a single clear and concise response.
#
# === FINAL SUMMARY ===
#
# Aktuelle Trends, die die Zukunft der Energiebranche prägen, lassen sich in drei sich ergänzende Bereiche gliedern: regulatorische Entwicklungen, technologische Innovationen und Marktdynamiken.
#
# 1. **Nachhaltigkeit und Dekarbonisierung:**
# Die Energiewende hin zu einer klimafreundlichen Versorgung steht im Zentrum. In der Schweiz treiben das revidierte Energiegesetz, die Energiestrategie 2050 und das verschärfte CO2-Gesetz den Ausbau erneuerbarer Energien (Solar, Wind, Wasserkraft, Biomasse) sowie die Reduktion fossiler Brennstoffe voran. Weltweit fördern CO2-Steuern, Emissionshandelssysteme und Investitionsprogramme den Übergang zu sauberen Technologien.
#
# 2. **Dezentralisierung und Digitalisierung:**
# Die Energieerzeugung wandert von zentralen Großkraftwerken zu dezentralen, oft erneuerbaren Erzeugern (z.B. Photovoltaik auf Hausdächern). Intelligente Netze (Smart Grids), digitale Messsysteme und Technologien wie IoT, KI und Blockchain ermöglichen eine effiziente Steuerung, Integration und flexible Nutzung der Energieflüsse in Echtzeit.
#
# 3. **Energiespeicherung und Flexibilisierung:**
# Fortschritte bei Batteriespeichern (Lithium-Ionen, Festkörperbatterien), Power-to-X-Technologien (Wasserstoff, synthetische Kraftstoffe) und Demand-Response-Systemen gleichen die Volatilität erneuerbarer Energien aus. Dies stärkt Netzstabilität und Versorgungssicherheit.
#
# 4. **Sektorkopplung und neue Energieträger:**
# Die zunehmende Elektrifizierung von Verkehr, Industrie und Gebäuden sowie die Kopplung der Sektoren Strom, Wärme und Mobilität schaffen neue Synergien und Geschäftsmodelle. Grüner Wasserstoff gilt als Schlüsseltechnologie zur Dekarbonisierung schwer elektrifizierbarer Bereiche wie Luftfahrt und Schwerindustrie.
#
# 5. **Marktentwicklung und neue Geschäftsmodelle:**
# Innovative Marktmodelle wie Peer-to-Peer-Energiehandel, Energie-Communities und Abonnements für Energiedienstleistungen entstehen. Gleichzeitig fördern Liberalisierung, regulatorische Anpassungen und internationale Vernetzung (z.B. Stromnetz-Integration) Wettbewerb und Versorgungssicherheit.
#
# Zusammenfassend transformiert sich die Energiebranche durch ein Zusammenspiel von politischen Rahmenbedingungen, technologischen Fortschritten und veränderten Markt- und Verbraucheranforderungen zu einer nachhaltigen, flexiblen und digitalisierten Energiezukunft. Unternehmen, die diese Trends aktiv gestalten und in Innovationen investieren, sichern ihre Wettbewerbsfähigkeit langfristig.
